# %%
import os
import sys
parent_dir = os.path.abspath("..")
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
from tqdm.notebook import tqdm
import experiments.datasets as datasets
from experiments.utils import multi_run_simulation
from models.alif import Alif

for dataset_name in (pbar:=tqdm(datasets.small_datasets_names, leave=False)):
    pbar.set_description(dataset_name)
    sim_res = multi_run_simulation(
        model=Alif(parallel_jobs=16, n_trees=16),
        n_runs=10,
        n_iter=25,
        dataset_name=dataset_name,
        save_path=f"sim_results/alif/{dataset_name}.gz"
    )
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8432\1534535658.py in <module>
#       6 for dataset_name in (pbar:=tqdm(datasets.small_datasets_names, leave=False)):
#       7     pbar.set_description(dataset_name)
# ----> 8     sim_res = multi_run_simulation(
#       9         model=Alif(parallel_jobs=16, n_trees=16),
#      10         n_runs=10,
#
# c:\Users\dsart\OneDrive\Desktop\balif+\experiments\utils.py in multi_run_simulation(model, n_runs, n_iter, dataset_name, test_size, save_path)
#     113             dataset_name=dataset_name, random_state=run_idx, test_size=test_size
#     114         )
# --> 115         sim_res[f"run_{run_idx}"] = simulate_run(
#     116             model=model,
#     117             n_iter=n_iter,
#
# ...
