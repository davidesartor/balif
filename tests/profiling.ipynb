# %%
import os, sys
parent_dir = os.path.abspath("..")
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %% [markdown]
# IF

# %%
import snakeviz
# %load_ext snakeviz

import datasets
from src.iforest import IsolationForest

data, labels = datasets.load()
iforest = IsolationForest()

# %snakeviz -t iforest.fit(data)

# %snakeviz -t iforest.predict(data)
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
#
# *** Profile stats marshalled to file 'C:\\Users\\dsart\\AppData\\Local\\Temp\\tmprn3__5lx'.
# Opening SnakeViz in a new tab...
#
# *** Profile stats marshalled to file 'C:\\Users\\dsart\\AppData\\Local\\Temp\\tmprnl5vkbs'.
# Opening SnakeViz in a new tab...

# %% [markdown]
# ALIF on simulation

# %%
import snakeviz
# %load_ext snakeviz

import experiments.datasets as datasets
from models.alif import Alif
from experiments.utils import multi_run_simulation

dataset = "wine"
data, labels = datasets.load(dataset)
# %snakeviz -t sim_res = multi_run_simulation(Alif(parallel_jobs=1), 1, 25, dataset)
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# *** Profile stats marshalled to file 'C:\\Users\\dsart\\AppData\\Local\\Temp\\tmp9we8zgdo'.
# Opening SnakeViz in a new tab...
