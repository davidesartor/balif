# %%
import os, sys
parent_dir = os.path.abspath("..")
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import datasets
from src.iforest import IsolationForest

from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve

for dataset_name in tqdm(datasets.small_datasets_names, desc="Datasets"):
    data, labels = datasets.load(dataset_name)
    iforest = IsolationForest(parallel_jobs=8)
    scores = iforest.fit_predict(data)
    
    precision, recall, _ = precision_recall_curve(labels, scores)
    average_precision = average_precision_score(labels, scores)
    
    plt.figure()
    plt.plot(recall, precision)
    plt.title(f"Precision-Recall curve for {dataset_name} (AP={average_precision:.2f})")
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.show()
# Out:
# Datasets:   0%|          | 0/14 [00:00<?, ?it/s]

# %%
import snakeviz
# %load_ext snakeviz

import datasets
from src.iforest import IsolationForest

data, labels = datasets.load()
iforest = IsolationForest()

# %snakeviz -t iforest.fit(data)

# %snakeviz -t iforest.predict(data)
# Out:
#
# *** Profile stats marshalled to file 'C:\\Users\\dsart\\AppData\\Local\\Temp\\tmpy1zoh85r'.
# Opening SnakeViz in a new tab...
#
# *** Profile stats marshalled to file 'C:\\Users\\dsart\\AppData\\Local\\Temp\\tmp8bnkz34k'.
# Opening SnakeViz in a new tab...
