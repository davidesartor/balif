# %%
import os, sys
parent_dir = os.path.abspath("..")
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
import datasets

print(f"small datasets:\n")
for name in datasets.small_datasets_names:
    print(f"{name}")
    
print(f"\nlarge datasets:\n")
for name in datasets.large_datasets_names:
    print(f"{name}")
    
assert datasets.datasets_names == datasets.small_datasets_names + datasets.large_datasets_names
# Out:
# small datasets:
#
# wine
# vertebral
# ionosphere
# wbc
# squarethoroid
# breastw
# pima
# vowels
# letter
# cardio
# thyroid
# optdigits
# satimage-2
# satellite
#
# large datasets:
#
# pendigits
# annthyroid
# cover
# mammography
# mnist

# %%
for dataset_name in datasets.datasets_names:
    print(dataset_name)
    data, labels = datasets.load(dataset_name)
    assert data.shape[0] == labels.shape[0]
    print(f"{data.shape=}, {data.dtype=}")
# Out:
# wine
# data.shape=(129, 13), data.dtype=dtype('float32')
# vertebral
# data.shape=(240, 6), data.dtype=dtype('float32')
# ionosphere
# data.shape=(351, 33), data.dtype=dtype('float32')
# wbc
# data.shape=(378, 30), data.dtype=dtype('float32')
# squarethoroid
# data.shape=(476, 2), data.dtype=dtype('float32')
# breastw
# data.shape=(683, 9), data.dtype=dtype('float32')
# pima
# data.shape=(768, 8), data.dtype=dtype('float32')
# vowels
# data.shape=(1456, 12), data.dtype=dtype('float32')
# letter
# data.shape=(1600, 32), data.dtype=dtype('float32')
# cardio
# data.shape=(1831, 21), data.dtype=dtype('float32')
# thyroid
# data.shape=(3772, 6), data.dtype=dtype('float32')
# optdigits
# data.shape=(5216, 64), data.dtype=dtype('float32')
# satimage-2
# data.shape=(5803, 36), data.dtype=dtype('float32')
# satellite
# data.shape=(6435, 36), data.dtype=dtype('float32')
# pendigits
# data.shape=(6870, 16), data.dtype=dtype('float32')
# annthyroid
# data.shape=(7200, 6), data.dtype=dtype('float32')
# cover
# data.shape=(286048, 10), data.dtype=dtype('float32')
# mammography
# data.shape=(11183, 6), data.dtype=dtype('float32')
# mnist
# data.shape=(7603, 100), data.dtype=dtype('float32')
