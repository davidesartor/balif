# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Othercomputers/Il mio laptop/balif
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-435c3350815a> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3 get_ipython().run_line_magic('cd', '/content/drive/Othercomputers/Il mio laptop/balif')
#
# ModuleNotFoundError: No module named 'google'

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings 
from tqdm.notebook import tqdm
warnings.filterwarnings('ignore')
#plt.style.use('dark_background')

# %%
import datasets
from utils import *
from balif import BALIF, BALEIF

# %%
n_runs = 10
max_iterations = 25
verbose=False

# %% [markdown]
# # simulations

# %%
for querystrat in tqdm(["random","margin", "anomalous"]):
    for ensamblepred in tqdm(["naive", "maxlikelihood"]):
        for i,name in enumerate(tqdm(["squarethoroid"]+datasets.datasets_names)):  
            data, labels = datasets.load_dataset(name)
            
            model = BALIF(query_strategy=querystrat, ensamble_prediction=ensamblepred)
            performance_logs = evaluate_performance(model,data,labels,n_runs,max_iterations,size_query=512,test_size=0.2)
            np.save(f"performance/{name}_BALIF_query-{querystrat}_prediction-{ensamblepred}",performance_logs, allow_pickle=True)
            
            model = BALEIF(query_strategy=querystrat, ensamble_prediction=ensamblepred)
            performance_logs = evaluate_performance(model,data,labels,n_runs,max_iterations,size_query=512,test_size=0.2)
            np.save(f"performance/{name}_BALEIF_query-{querystrat}_prediction-{ensamblepred}",performance_logs, allow_pickle=True)
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b85124542467> in <module>
#       5
#       6             model = BALIF(query_strategy=querystrat, ensamble_prediction=ensamblepred)
# ----> 7             performance_logs = evaluate_performance(model,data,labels,n_runs,max_iterations,size_query=512,test_size=0.2)
#       8             np.save(f"performance/{name}_BALIF_query-{querystrat}_prediction-{ensamblepred}",performance_logs, allow_pickle=True)
#       9
#
# ~\Desktop\balif\utils.py in evaluate_performance(model, data, labels, n_runs, max_iterations, size_query, test_size)
#      56             queried[idx] = True
#      57
# ---> 58             auc,ap = get_accuracy(model.predict(X_test),y_test)
#      59             performance_logs[f"run n:{run}"].append((auc,ap))
#      60     return performance_logs
#
# ...

# %%
for querystrat in tqdm(["random","margin", "anomalous"]):
    for ensamblepred in tqdm(["naive", "maxlikelihood"]):
        for i,name in enumerate(tqdm(["squarethoroid"])):  
            data, labels = datasets.load_dataset(name)
            
            model = BALIF(query_strategy=querystrat, ensamble_prediction=ensamblepred)
            performance_logs = evaluate_performance(model,data,labels,n_runs,max_iterations,size_query=512,test_size=0.2)
            np.save(f"performance/{name}_BALIF_query-{querystrat}_prediction-{ensamblepred}",performance_logs, allow_pickle=True)
            
            model = BALEIF(query_strategy=querystrat, ensamble_prediction=ensamblepred)
            performance_logs = evaluate_performance(model,data,labels,n_runs,max_iterations,size_query=512,test_size=0.2)
            np.save(f"performance/{name}_BALEIF_query-{querystrat}_prediction-{ensamblepred}",performance_logs, allow_pickle=True)
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(8,8),dpi=80)
for i,name in tqdm(enumerate(tqdm(["squarethoroid"]))): 
    plt.title(name)
    for ensamblepred in ["naive", "maxlikelihood"]:
        for querystrat in ["anomalous","margin"]:
            prova = np.load(f"performance/{name}_BALEIF_query-{querystrat}_prediction-{ensamblepred}.npy", allow_pickle=True).item()
            plt_perf_evol(prova,label=f" BALEIF ({querystrat}, {ensamblepred})")
plt.figure(figsize=(8,8),dpi=80)
for i,name in tqdm(enumerate(tqdm(["squarethoroid"]))): 
    plt.title(name)
    for ensamblepred in ["naive", "maxlikelihood"]:
        for querystrat in ["anomalous","margin"]:
            prova = np.load(f"performance/{name}_BALIF_query-{querystrat}_prediction-{ensamblepred}.npy", allow_pickle=True).item()
            plt_perf_evol(prova,label=f" BALIF ({querystrat}, {ensamblepred})")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# # Plots

# %%
plt.figure(figsize=(8,8),dpi=80)
for i,name in tqdm(enumerate(tqdm(["squarethoroid"]))): 
    plt.title(name)
    for ensamblepred in ["naive", "maxlikelihood"]:
        for querystrat in ["anomalous","margin"]:
            prova = np.load(f"performance/{name}_BALEIF_query-{querystrat}_prediction-{ensamblepred}.npy", allow_pickle=True).item()
            plt_perf_evol(prova,label=f" BALEIF ({querystrat}, {ensamblepred})")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
c=2
plt.figure(figsize=(2*4*c,2*4*16//c),dpi=80)
for i,name in tqdm(enumerate(tqdm(datasets.datasets_names))): 
    plt.subplot(16//c,c,i+1)
    plt.title(name)
    for ensamblepred in ["naive", "maxlikelihood"]:
        for querystrat in ["anomalous","margin"]:
            prova = np.load(f"performance/{name}_BALEIF_query-{querystrat}_prediction-{ensamblepred}.npy", allow_pickle=True).item()
            plt_perf_evol(prova,label=f" BALEIF ({querystrat}, {ensamblepred})")
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
