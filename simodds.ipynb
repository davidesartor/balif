# %%
import os
#%env JAX_PLATFORMS=cpu
# %env CUDA_VISIBLE_DEVICES=0
# %env XLA_PYTHON_CLIENT_PREALLOCATE=false
os.chdir('..')
from tqdm.auto import tqdm
import jax
import jax.numpy as jnp
import jax.random as jr
import equinox as eqx
import numpy as np
import comet_ml
import matplotlib.pyplot as plt
from sklearn.metrics import average_precision_score as avg_precision

import odds_datasets
from balif import Balif

# %%
model_configs: list[dict] = []
for query_strategy in ["margin", "random"]:
    for p_normal_idx in ["uniform", "range"]:
        for hyperplane_components in [1, -1]:
            model_configs.append(
                dict(
                    n_estimators=128,
                    max_samples=256,
                    bootstrap=True,
                    standardize=False,
                    hyperplane_components=hyperplane_components,
                    p_normal_idx=p_normal_idx,
                    p_normal_value="uniform",
                    p_intercept="uniform",
                    prior_sample_size=0.1,
                    score_reduction="mean",
                    query_strategy=query_strategy,
                )
            )

# %%
@eqx.filter_jit
def run_fn(model_config, data, labels, key):
    def scan_body(carry, key):
        key_score, key_query, key_update = jr.split(key, 3)
        model, queriable = carry

        scores = model.score(data, key=key_score)

        interests = model.interest(data, key=key_query)
        query_idx = jnp.where(queriable, interests, interests.min()).argmax()
        queriable = queriable.at[query_idx].set(False)
        point, is_anomaly = data[query_idx], labels[query_idx]

        model = model.register(point, is_anomaly=is_anomaly, key=key_update)
        return (model, queriable), scores

    samples, dim = data.shape
    iterations = 1 + samples//10
    rng_fit, rng_steps = jr.split(key)
    model = Balif(**model_config)
    model = model.fit(data, key=rng_fit)
    
    queriable = jnp.ones(samples, dtype=bool)
    _, scores = jax.lax.scan(
        scan_body, (model, queriable), jr.split(rng_steps, iterations)
    )
    return scores

# %%
comet_ml.init()
for model_config in tqdm(model_configs, desc="models"):
    for seed in range(32):
        experiment = comet_ml.OfflineExperiment(project_name="balif", offline_directory="comet")
        experiment.log_parameters({"seed":seed,**model_config})

        for dataset_name in  tqdm(odds_datasets.datasets_names, desc="datasets"):
            data, labels = odds_datasets.load(dataset_name)

            with experiment.context_manager(dataset_name):
                sim_results = run_fn(model_config, data, labels, jr.key(seed))

                for step, scores in enumerate(sim_results):
                    ap = avg_precision(labels, scores)
                    experiment.log_metric("average_precision", ap, step)
        experiment.end()
# !comet upload comet/*.zip

# %%
# !comet upload comet/*.zip
# Out:
# COMET INFO: Attempting to upload 'comet/05c19b2cf1414364bccd36362bd30ea3.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/05c19b2cf1414364bccd36362bd30ea3
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/125c4b3bf2054f06bfb622adbf5185a2.zip'...
# COMET ERROR: Upload failed for 'comet/125c4b3bf2054f06bfb622adbf5185a2.zip'; unknown error
# Traceback (most recent call last):
#   File "/home/davide_sartor/.conda/envs/torch_env/lib/python3.12/site-packages/comet_ml/offline.py", line 2367, in main_upload
#     success = upload_single_offline_experiment(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/davide_sartor/.conda/envs/torch_env/lib/python3.12/site-packages/comet_ml/offline.py", line 2299, in upload_single_offline_experiment
#     sender = OfflineSender(
#              ^^^^^^^^^^^^^^
#   File "/home/davide_sartor/.conda/envs/torch_env/lib/python3.12/site-packages/comet_ml/offline.py", line 778, in __init__
#     self._read_experiment_file()
#   File "/home/davide_sartor/.conda/envs/torch_env/lib/python3.12/site-packages/comet_ml/offline.py", line 861, in _read_experiment_file
#     with io.open(
#          ^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpdpy24tpe/experiment.json'
# COMET INFO: Attempting to upload 'comet/16082b6df74b4ca681294e408e08a1d4.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/16082b6df74b4ca681294e408e08a1d4
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/23b64c9201264694b417974d4ddf09b0.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/23b64c9201264694b417974d4ddf09b0
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/2c3f8cabeb734bc7a14c745dace7285c.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/2c3f8cabeb734bc7a14c745dace7285c
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/36c94f138ed147aa871c6c1308d2da88.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/36c94f138ed147aa871c6c1308d2da88
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/3b1bfc9cc48d4eb2bb8c664528bbc84d.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/3b1bfc9cc48d4eb2bb8c664528bbc84d
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/466c80758b6341818542f84a37a15fae.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/466c80758b6341818542f84a37a15fae
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/4905dc987b8042a1bcf4615a8ad22b22.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/4905dc987b8042a1bcf4615a8ad22b22
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/55323cbccb78488b843a36fea277456d.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/55323cbccb78488b843a36fea277456d
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/5a963dbc41a04a00a874a85aa49d44bb.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/5a963dbc41a04a00a874a85aa49d44bb
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/634ac9d812fe48148c9f132642c7107b.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/634ac9d812fe48148c9f132642c7107b
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/6c1bb3cb4b9f4da7b84e1edde353cf24.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/6c1bb3cb4b9f4da7b84e1edde353cf24
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/70de625bddc5407880f9a412125ec2cc.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/70de625bddc5407880f9a412125ec2cc
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/8d4025b320d74607b540cbe19c6768c3.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/8d4025b320d74607b540cbe19c6768c3
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/928817fc0525441bbf16c350da01ceed.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/928817fc0525441bbf16c350da01ceed
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/9416a8e8ee08476faccbeb948e1843b6.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/9416a8e8ee08476faccbeb948e1843b6
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/994517937d544978910c67a1247f63a5.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/994517937d544978910c67a1247f63a5
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/a326dcf4a293484abe3b5432294f1cf3.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/a326dcf4a293484abe3b5432294f1cf3
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/a9bf06c3b71b4ce897ec75fc35ca4cf2.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/a9bf06c3b71b4ce897ec75fc35ca4cf2
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/b705a79820ec403cad661816121d1250.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/b705a79820ec403cad661816121d1250
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/bae392a8c9554df1a1e52eb70a88bfe4.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/bae392a8c9554df1a1e52eb70a88bfe4
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/c9980a9415144ceaa5f8e1c9218c8745.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/c9980a9415144ceaa5f8e1c9218c8745
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/ce0a1cd353de47b7a471849134faeb55.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/ce0a1cd353de47b7a471849134faeb55
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Attempting to upload 'comet/e29e848ca1624e3cbf8f1bcf1b4da875.zip'...
# COMET INFO: Starting the upload of the experiment
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The offline experiment has been uploaded on comet.com https://www.comet.com/davidesartor/balif/e29e848ca1624e3cbf8f1bcf1b4da875
#
# COMET INFO: Offline Experiment will now be processed---may take some time to appear on the Comet dashboard.
# COMET INFO:     Done!
# COMET INFO: Number of uploaded experiments: 24
# COMET INFO: Number of failed experiment uploads: 1
# COMET ERROR: At least one experiment failed to upload, check COMET ERROR messages above for more information.
