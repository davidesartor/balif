# %%
# %env CUDA_VISIBLE_DEVICES=0
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.5
from tqdm.auto import tqdm
import jax
import jax.numpy as jnp
import odds_datasets

from balif import Balif
from sklearn.metrics import average_precision_score
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# env: XLA_PYTHON_CLIENT_MEM_FRACTION=0.5

# %%
def run_sim(rng, train_data, train_labels, test_data, hyperplane_components, label_batch_size):
    def scan_body(carry, key):
        model, queriable = carry
        scores = model.score_samples(test_data)

        if label_batch_size > 1:
            raise NotImplementedError("@Davide Rembember you disabled this for testing pathscore")

        # interests = model.interest_for(train_data)
        # queries_idx = jnp.where(queriable, interests, interests.min()).argmax()
        queries_idx = jax.random.choice(key, len(queriable))
        #queriable = queriable.at[queries_idx].set(False)
        model = model.register(train_data[queries_idx], train_labels[queries_idx])
        return (model, queriable), scores

    iterations = 1 + train_data.shape[0] // (10 * label_batch_size)
    rng_init, rng_steps = jax.random.split(rng)
    model = Balif.fit(rng_init, train_data, hyperplane_components=hyperplane_components)
    queriable = jnp.ones(train_data.shape[0], dtype=bool)
    _, scores = jax.lax.scan(scan_body, (model, queriable), jax.random.split(rng_steps, iterations))
    return scores


jitted_vectorized_run_sim = jax.jit(
    jax.vmap(run_sim, in_axes=(0, None, None, None, None, None)),
    static_argnames=("hyperplane_components", "label_batch_size"),
)

# %%
seed = 42
n_sims = 32
rng_keys = jax.random.split(jax.random.PRNGKey(seed), n_sims)

# %%
for dataset_name in (pbar := tqdm(odds_datasets.datasets_names)):
    if dataset_name in ["cover"]:  # cover is so large it causes OOM
        continue

    data, labels = odds_datasets.load(dataset_name)
    train_data = test_data = data
    train_labels = test_labels = labels

    pbar.set_description(f"{dataset_name}, shape: {data.shape}")

    # fitting the base model on a train-test split would be more correct here, but the base
    # score would not match the literature, and would look like we have a wrong implementation
    # train_data, test_data, train_labels, test_labels = odds_datasets.load_as_train_test(
    #     dataset_name, test_size=0.5, random_state=seed
    # )
    # for hyperplane_components, label_batch_size in tqdm(
    #     list(zip([1, 1, 1, 1], [1, 2, 4, 8])), desc="models", leave=False
    # ):
    for hyperplane_components, label_batch_size in tqdm(
        list(zip([1, None], [1, 1])), desc="models", leave=False
    ):
        scores = jitted_vectorized_run_sim(
            rng_keys, train_data, train_labels, test_data, hyperplane_components, label_batch_size
        )
        ap = jnp.array(
            [[average_precision_score(test_labels, s) for s in run_scores] for run_scores in scores]
        )
        ap_mean, ap_std = ap.mean(axis=0), ap.std(axis=0)
        save_path = f"results/{dataset_name}_balif_{hyperplane_components=}_{label_batch_size=}.npy"
        jnp.save(save_path, ap, allow_pickle=True)
# Out:
# ...
# models:   0%|          | 0/2 [00:00<?, ?it/s]
