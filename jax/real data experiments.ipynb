# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
from tqdm.auto import tqdm
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import odds_datasets

from balif import Balif
from sklearn.metrics import precision_recall_curve, average_precision_score

# %%
seed = 42
rng = jax.random.PRNGKey(seed)

iterations = 25

for dataset_name in tqdm(odds_datasets.small_datasets_names):


    data, labels = odds_datasets.load(dataset_name)
    train_data, test_data, train_labels, test_labels = odds_datasets.load_as_train_test(
        dataset_name, test_size=0.5, random_state=seed
    )

    balif = Balif.fit(rng, data, hyperplane_components=1)
    ebalif = Balif.fit(rng, data, hyperplane_components=None)

    for model, label in [(balif, "balif"), (ebalif, "e-balif")]:
        ap = [average_precision_score(test_labels, model.score_samples(test_data))]

        queriable = jnp.ones(len(train_data)).astype(bool)
        for i in range(iterations):
            interests = model.interest_for(train_data)
            query_idx = jnp.where(queriable, interests, 0.0).argmax()
            forest = model.register(train_data[query_idx], train_labels[query_idx])
            queriable = queriable.at[query_idx].set(False)

            ap.append(average_precision_score(test_labels, forest.score_samples(test_data)))

        plt.plot(ap, label=dataset_name)
        plt.ylim(0, 1)
        plt.show()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
