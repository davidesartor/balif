# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from balif import Balif
import odds_datasets

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, auc, average_precision_score

data, labels = odds_datasets.load("annthyroid")
train_data, test_data, train_labels, test_labels = train_test_split(
    data, labels, test_size=0.3, random_state=42, stratify=labels
)
train_data = jnp.array(train_data)
test_data = jnp.array(test_data)
train_labels = jnp.array(train_labels)
test_labels = jnp.array(test_labels)

# %%
n_trees = 128
subsample_size = 256
hyperplane_components = None

rng_split, rng_sim, rng_forest = jax.random.split(jax.random.PRNGKey(42), 3)
forest = Balif.fit(rng_forest, train_data, n_trees, subsample_size, hyperplane_components)
x, y, _ = precision_recall_curve(test_labels, forest.score_samples(test_data))
plt.plot(y, x, label="Balif")
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
x, y, _ = precision_recall_curve(test_labels, forest.score_samples(test_data))
plt.plot(y, x, label="Balif")
plt.ylim(0, 1)

N_labels = 100
for rng in jax.random.split(rng_sim, N_labels):
    idx = jax.random.choice(rng, train_data.shape[0])
    forest = forest.register(train_data[idx], is_anomaly=bool(train_labels[idx]))
    
x, y, _ = precision_recall_curve(test_labels, forest.score_samples(test_data))
plt.plot(y, x, label="Balif")
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=128, random_state=42)
idx = jax.random.choice(rng_split, train_data.shape[0], shape=(100,), replace=False)
clf.fit(train_data[idx], train_labels[idx])
x, y, _ = precision_recall_curve(test_labels, clf.predict_proba(test_data)[:, 1])
plt.plot(y, x, label="RF")
